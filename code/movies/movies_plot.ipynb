# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('ggplot')

# %%
years_df = pd.read_csv('general/years.csv')
years_x = years_df['startYear']
average_rating_year_y = years_df['averageRating_mean']
plt.plot(years_x, average_rating_year_y)
plt.title('Average Movie Rating by Year')
plt.xlabel('Years')
plt.ylabel('Average Movie Rating')
plt.show()

# %%
years_Action_df = pd.read_csv('genres/Action/years.csv')
years_Adventure_df = pd.read_csv('genres/Adventure/years.csv')
years_Animation_df = pd.read_csv('genres/Animation/years.csv')
years_Biography_df = pd.read_csv('genres/Biography/years.csv')
years_Comedy_df = pd.read_csv('genres/Comedy/years.csv')
years_Crime_df = pd.read_csv('genres/Crime/years.csv')
years_Documentary_df = pd.read_csv('genres/Documentary/years.csv')
years_Drama_df = pd.read_csv('genres/Drama/years.csv')
years_Family_df = pd.read_csv('genres/Family/years.csv')
years_Fantasy_df = pd.read_csv('genres/Fantasy/years.csv')
years_FilmNoir_df = pd.read_csv('genres/Film-Noir/years.csv')
years_History_df = pd.read_csv('genres/History/years.csv')
years_Horror_df = pd.read_csv('genres/Horror/years.csv')
years_Music_df = pd.read_csv('genres/Music/years.csv')
years_Musical_df = pd.read_csv('genres/Musical/years.csv')
years_Mystery_df = pd.read_csv('genres/Mystery/years.csv')
years_Romance_df = pd.read_csv('genres/Romance/years.csv')
years_SciFi_df = pd.read_csv('genres/Sci-Fi/years.csv')
years_Sport_df = pd.read_csv('genres/Sport/years.csv')
years_Thriller_df = pd.read_csv('genres/Thriller/years.csv')
years_War_df = pd.read_csv('genres/War/years.csv')
years_Western_df = pd.read_csv('genres/Western/years.csv')

# %%
plt.plot(years_x, average_rating_year_y, label='general')

average_rating_year_Action_y = years_Action_df['averageRating_mean']
years_Action_x = years_Action_df['startYear']
plt.plot(years_Action_x, average_rating_year_Action_y, label='Action')

average_rating_year_Adventure_y = years_Adventure_df['averageRating_mean']
years_Adventure_x = years_Adventure_df['startYear']
plt.plot(years_Adventure_x, average_rating_year_Adventure_y, label='Adventure')

average_rating_year_Animation_y = years_Animation_df['averageRating_mean']
years_Animation_x = years_Animation_df['startYear']
plt.plot(years_Animation_x, average_rating_year_Animation_y, label='Animation')

average_rating_year_Biography_y = years_Biography_df['averageRating_mean']
years_Biography_x = years_Biography_df['startYear']
plt.plot(years_Biography_x, average_rating_year_Biography_y, label='Biography')

average_rating_year_Comedy_y = years_Comedy_df['averageRating_mean']
years_Comedy_x = years_Comedy_df['startYear']
plt.plot(years_Comedy_x, average_rating_year_Comedy_y, label='Comedy')

average_rating_year_Crime_y = years_Crime_df['averageRating_mean']
years_Crime_x = years_Crime_df['startYear']
plt.plot(years_Crime_x, average_rating_year_Crime_y, label='Crime')

average_rating_year_Documentary_y = years_Documentary_df['averageRating_mean']
years_Documentary_x = years_Documentary_df['startYear']
plt.plot(years_Documentary_x, average_rating_year_Documentary_y, label='Documentary')

average_rating_year_Drama_y = years_Drama_df['averageRating_mean']
years_Drama_x = years_Drama_df['startYear']
plt.plot(years_Drama_x, average_rating_year_Drama_y, label='Drama')

average_rating_year_Family_y = years_Family_df['averageRating_mean']
years_Family_x = years_Family_df['startYear']
plt.plot(years_Family_x, average_rating_year_Family_y, label='Family')

average_rating_year_Fantasy_y = years_Fantasy_df['averageRating_mean']
years_Fantasy_x = years_Fantasy_df['startYear']
plt.plot(years_Fantasy_x, average_rating_year_Fantasy_y, label='Fantasy')

average_rating_year_FilmNoir_y = years_FilmNoir_df['averageRating_mean']
years_FilmNoir_x = years_FilmNoir_df['startYear']
plt.plot(years_FilmNoir_x, average_rating_year_FilmNoir_y, label='FilmNoir')

average_rating_year_History_y = years_History_df['averageRating_mean']
years_History_x = years_History_df['startYear']
plt.plot(years_History_x, average_rating_year_History_y, label='History')

average_rating_year_Horror_y = years_Horror_df['averageRating_mean']
years_Horror_x = years_Horror_df['startYear']
plt.plot(years_Horror_x, average_rating_year_Horror_y, label='Horror')

average_rating_year_Music_y = years_Music_df['averageRating_mean']
years_Music_x = years_Music_df['startYear']
plt.plot(years_Music_x, average_rating_year_Music_y, label='Music')

average_rating_year_Musical_y = years_Musical_df['averageRating_mean']
years_Musical_x = years_Musical_df['startYear']
plt.plot(years_Musical_x, average_rating_year_Musical_y, label='Musical')

average_rating_year_Mystery_y = years_Mystery_df['averageRating_mean']
years_Mystery_x = years_Mystery_df['startYear']
plt.plot(years_Mystery_x, average_rating_year_Mystery_y, label='Mystery')

average_rating_year_Romance_y = years_Romance_df['averageRating_mean']
years_Romance_x = years_Romance_df['startYear']
plt.plot(years_Romance_x, average_rating_year_Romance_y, label='Romance')

average_rating_year_SciFi_y = years_SciFi_df['averageRating_mean']
years_SciFi_x = years_SciFi_df['startYear']
plt.plot(years_SciFi_x, average_rating_year_SciFi_y, label='SciFi')

average_rating_year_Sport_y = years_Sport_df['averageRating_mean']
years_Sport_x = years_Sport_df['startYear']
plt.plot(years_Sport_x, average_rating_year_Sport_y, label='Sport')

average_rating_year_Thriller_y = years_Thriller_df['averageRating_mean']
years_Thriller_x = years_Thriller_df['startYear']
plt.plot(years_Thriller_x, average_rating_year_Thriller_y, label='Thriller')

average_rating_year_War_y = years_War_df['averageRating_mean']
years_War_x = years_War_df['startYear']
plt.plot(years_War_x, average_rating_year_War_y, label='War')

average_rating_year_Western_y = years_Western_df['averageRating_mean']
years_Western_x = years_Western_df['startYear']
plt.plot(years_Western_x, average_rating_year_Western_y, label='Western')
plt.show()

# %%
year_count_y = years_df['count']
plt.plot(years_x, year_count_y)
plt.title('Released Films by Year')
plt.xlabel('Years')
plt.ylabel('Released Films')
plt.show()

# %%
decades_df = pd.read_csv('general/decades.csv')
decades_x = decades_df['decade']
average_rating_decade_y = decades_df['averageRating_mean']
plt.plot(decades_x, average_rating_decade_y)
plt.title('Average Movie Rating by Decade')
plt.xlabel('Decades')
plt.ylabel('Average Rating')
plt.show()

# %%
runtime_df = pd.read_csv('general/runtimeInterval.csv')
runtime_x = runtime_df['runtimeInterval']
average_rating_runtime_y = runtime_df['averageRating_mean']
plt.plot(runtime_x, average_rating_runtime_y)
plt.title('Average Movie Rating by RunTime Interval')
plt.xlabel('RunTime Interval')
plt.ylabel('Average Movie Rating')
plt.show()
